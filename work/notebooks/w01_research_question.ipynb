# %% [markdown]
# <a href="https://colab.research.google.com/github/Laiba-Tahir29/Machine_learning_internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# **Lane: Refresh / Content Opportunity Scoring**
# I chose this lane becasue i wanted to check which pages of a website needs the improvement and why? so that ultimately all pages work well.
# Like my model will check through the data that which pages need to be updated first and then it will update them in that sequence.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Which page needs to be fixed first , this decision will be improved.
# The SEO  manager will look into the pages on a weekly basis and will take the decision to fix those pages.Wrong recommendation would result in fxing those pages which do not need any updation and will afect those pages which somewhat need to be fixed.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import subprocess, os
if not os.path.isdir("/content/Machine_learning_internship"):
    subprocess.run(["git", "clone", "https://github.com/Laiba-Tahir29/Machine_learning_internship.git"], check=True)
os.chdir("/content/Machine_learning_internship")

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

stale_visible = ((df["days_since_last_update"] >= 180) & (df["impressions_90d"] >= 500)).sum()
print(f"Pages that are stale (180+ days) AND visible (500+ impressions): {stale_visible} out of {len(df)}")

declining_rate = (df["trend_direction"].str.lower() == "down").mean()
print(f"Fraction of pages currently in a 'down' trend: {declining_rate:.1%}")

median_by_trend = df.groupby(df["trend_direction"].str.lower())["impressions_90d"].median()
print("\nMedian impressions_90d by trend direction:")
print(median_by_trend)
# Out:
# Pages that are stale (180+ days) AND visible (500+ impressions): 17 out of 30000
# Fraction of pages currently in a 'down' trend: 54.2%
#
# Median impressions_90d by trend direction:
# trend_direction
# down       961.0
# flat         4.0
# new          3.0
# stable    1944.5
# up         587.0
# Name: impressions_90d, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# **What I CAN claim:**
# - This work is decision-support — it helps an SEO manager decide which
#   pages to review first, based on observed signals (traffic, freshness,
#   trend).
# - I can say a decline is "associated with" certain signals — observed,
#   not proven cause.
# - My ranked list is directional, not a guarantee.
#
# **What I CANNOT claim:**
# - I will never claim to predict or understand Google's algorithm.
# - I will never claim fixing a page will definitely cause recovery — that  needs a real experiment, not just this data.
# - A "declining" label isn't certain — it could be seasonality or
#   consolidation, not a real problem.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
